# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\Youssouf\\Desktop\\Fullstack\\FULL_STACK_12_WEEK_PROGRAM-master\\S0.2 -- Data Visualisation & Collaboration\\Projet -- SPEED DATING\\Speed Dating Data.csv", encoding="ISO-8859-1")
data.head(6)
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
# 5    1  1.0       0    1       1     1     10         7       NaN      6  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# ...

# %%
desc = data.describe()
display(desc)
# Out:
#                iid           id       gender          idg       condtn  \
# count  8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# mean    283.675937     8.960248     0.500597    17.327166     1.828837
# std     158.583367     5.491329     0.500029    10.940735     0.376673
# min       1.000000     1.000000     0.000000     1.000000     1.000000
# 25%     154.000000     4.000000     0.000000     8.000000     2.000000
# 50%     281.000000     8.000000     1.000000    16.000000     2.000000
# 75%     407.000000    13.000000     1.000000    26.000000     2.000000
# max     552.000000    22.000000     1.000000    44.000000     2.000000
#
#               wave        round     position     positin1        order  ...  \
# count  8378.000000  8378.000000  8378.000000  6532.000000  8378.000000  ...
# mean     11.350919    16.872046     9.042731     9.295775     8.927668  ...
# std       5.995903     4.358458     5.514939     5.650199     5.477009  ...
# ...

# %% [markdown]
# gender, match, ("number of Speed <dates> you had" : numdat_2),("date length:  Four minutes is" : length), ("correlation between participant’s and partner’s ratings of interests in" : int_corr), samerace, age_o, race_o, dec_o, attr_o, field_cd, race, imprace, imprelig, career, career_c, sports, tvsports, art, gaming, ("ce que l'on cherche chez le sex opposé": attr1_1, sinc1_1, intel1_1, fun1_1, amb1_1, shar1_1), ("ce que le sex opposé cherche chez son part[think]": attr4_1, sinc4_1, intel4_1, fun4_1, amb4_1, shar4_1),("ce que le sex opposé cherche chez son part[think] lors date": attr2_1, sinc2_1, intel2_1, fun2_1, amb2_1, shar2_1), ("How do you measure up you": attr5_1, sinc5_1, intel5_1, fun5_1, amb5_1, shar5_1), (", how much do you like this person" : like), ("yes/no decisions best way that reflect imp of these attributes in your decisions : "attr7_2, sinc7_2, intel7_2, fun7_2, amb7_2, shar7_2)

# %%
data1 = data.loc[:, 'gender']
data2 = data.loc[:, 'match':'race_o']
data3 = data.loc[:, 'dec_o':'like_o']
data4 = data.loc[:, 'age':'field_cd']
data5 = data.loc[:, 'race':'imprelig']
data6 = data.loc[:, 'attr1_1':'like']
data6 = data6.drop(['attr3_1', 'sinc3_1', 'fun3_1', 'intel3_1', 'amb3_1'], axis=1)
data7 = data.loc[:, 'length':'shar7_2']

# %%
data = pd.concat((data1, data2, data3, data4, data5, data6, data7), axis=1)
data.head(6)
# Out:
#    gender  match  int_corr  samerace  age_o  race_o  dec_o  attr_o  sinc_o  \
# 0       0      0      0.14         0   27.0     2.0      0     6.0     8.0
# 1       0      0      0.54         0   22.0     2.0      0     7.0     8.0
# 2       0      1      0.16         1   22.0     4.0      1    10.0    10.0
# 3       0      1      0.61         0   23.0     2.0      1     7.0     8.0
# 4       0      1      0.21         0   24.0     3.0      1     8.0     7.0
# 5       0      0      0.25         0   25.0     2.0      1     7.0     7.0
#
#    intel_o  ...  shar  like  length  numdat_2  attr7_2 sinc7_2  intel7_2  \
# 0      8.0  ...   5.0   7.0     2.0       1.0      NaN     NaN       NaN
# 1     10.0  ...   6.0   7.0     2.0       1.0      NaN     NaN       NaN
# 2     10.0  ...   7.0   7.0     2.0       1.0      NaN     NaN       NaN
# 3      9.0  ...   8.0   7.0     2.0       1.0      NaN     NaN       NaN
# 4      9.0  ...   6.0   6.0     2.0       1.0      NaN     NaN       NaN
# ...

# %%
Nacount = pd.DataFrame(data = data.isnull().sum(), columns= ["nacount"])
Nacount
# Out:
#           nacount
# gender          0
# match           0
# int_corr      158
# samerace        0
# age_o         104
# race_o         73
# dec_o           0
# attr_o        212
# sinc_o        287
# intel_o       306
# fun_o         360
# amb_o         722
# shar_o       1076
# like_o        250
# age            95
# field          63
# field_cd       82
# race           63
# imprace        79
# imprelig       79
# attr1_1        79
# sinc1_1        79
# intel1_1       79
# fun1_1         89
# amb1_1         99
# shar1_1       121
# attr4_1      1889
# sinc4_1      1889
# intel4_1     1889
# fun4_1       1889
# amb4_1       1889
# shar4_1      1911
# attr2_1        79
# sinc2_1        79
# intel2_1       79
# fun2_1         79
# amb2_1         89
# shar2_1        89
# attr5_1      3472
# sinc5_1      3472
# intel5_1     3472
# fun5_1       3472
# amb5_1       3472
# dec             0
# attr          202
# sinc          277
# intel         296
# fun           350
# amb           712
# ...

# %%
data = data.drop(["shar7_2","amb7_2", "fun7_2", "intel7_2" ,"sinc7_2","attr7_2"], axis=1)
data.head(6)
# Out:
#    gender  match  int_corr  samerace  age_o  race_o  dec_o  attr_o  sinc_o  \
# 0       0      0      0.14         0   27.0     2.0      0     6.0     8.0
# 1       0      0      0.54         0   22.0     2.0      0     7.0     8.0
# 2       0      1      0.16         1   22.0     4.0      1    10.0    10.0
# 3       0      1      0.61         0   23.0     2.0      1     7.0     8.0
# 4       0      1      0.21         0   24.0     3.0      1     8.0     7.0
# 5       0      0      0.25         0   25.0     2.0      1     7.0     7.0
#
#    intel_o  ...  dec  attr  sinc  intel  fun  amb  shar  like  length  \
# 0      8.0  ...    1   6.0   9.0    7.0  7.0  6.0   5.0   7.0     2.0
# 1     10.0  ...    1   7.0   8.0    7.0  8.0  5.0   6.0   7.0     2.0
# 2     10.0  ...    1   5.0   8.0    9.0  8.0  5.0   7.0   7.0     2.0
# 3      9.0  ...    1   7.0   6.0    8.0  7.0  6.0   8.0   7.0     2.0
# 4      9.0  ...    1   5.0   6.0    7.0  7.0  6.0   6.0   6.0     2.0
# ...

# %%
data = data.drop(["amb5_1", "fun5_1", "intel5_1" ,"sinc5_1","attr5_1"], axis=1)
data.head(6)
# Out:
#    gender  match  int_corr  samerace  age_o  race_o  dec_o  attr_o  sinc_o  \
# 0       0      0      0.14         0   27.0     2.0      0     6.0     8.0
# 1       0      0      0.54         0   22.0     2.0      0     7.0     8.0
# 2       0      1      0.16         1   22.0     4.0      1    10.0    10.0
# 3       0      1      0.61         0   23.0     2.0      1     7.0     8.0
# 4       0      1      0.21         0   24.0     3.0      1     8.0     7.0
# 5       0      0      0.25         0   25.0     2.0      1     7.0     7.0
#
#    intel_o  ...  dec  attr  sinc  intel  fun  amb  shar  like  length  \
# 0      8.0  ...    1   6.0   9.0    7.0  7.0  6.0   5.0   7.0     2.0
# 1     10.0  ...    1   7.0   8.0    7.0  8.0  5.0   6.0   7.0     2.0
# 2     10.0  ...    1   5.0   8.0    9.0  8.0  5.0   7.0   7.0     2.0
# 3      9.0  ...    1   7.0   6.0    8.0  7.0  6.0   8.0   7.0     2.0
# 4      9.0  ...    1   5.0   6.0    7.0  7.0  6.0   6.0   6.0     2.0
# ...

# %%
data = data.drop(["shar4_1", "amb4_1", "fun4_1", "intel4_1" ,"sinc4_1","attr4_1"], axis =1)
data.head(6)
# Out:
#    gender  match  int_corr  samerace  age_o  race_o  dec_o  attr_o  sinc_o  \
# 0       0      0      0.14         0   27.0     2.0      0     6.0     8.0
# 1       0      0      0.54         0   22.0     2.0      0     7.0     8.0
# 2       0      1      0.16         1   22.0     4.0      1    10.0    10.0
# 3       0      1      0.61         0   23.0     2.0      1     7.0     8.0
# 4       0      1      0.21         0   24.0     3.0      1     8.0     7.0
# 5       0      0      0.25         0   25.0     2.0      1     7.0     7.0
#
#    intel_o  ...  dec  attr  sinc  intel  fun  amb  shar  like  length  \
# 0      8.0  ...    1   6.0   9.0    7.0  7.0  6.0   5.0   7.0     2.0
# 1     10.0  ...    1   7.0   8.0    7.0  8.0  5.0   6.0   7.0     2.0
# 2     10.0  ...    1   5.0   8.0    9.0  8.0  5.0   7.0   7.0     2.0
# 3      9.0  ...    1   7.0   6.0    8.0  7.0  6.0   8.0   7.0     2.0
# 4      9.0  ...    1   5.0   6.0    7.0  7.0  6.0   6.0   6.0     2.0
# ...

# %%
Nacount = pd.DataFrame(data = data.isnull().sum(), columns= ["nacount"])
Nacount
# Out:
#           nacount
# gender          0
# match           0
# int_corr      158
# samerace        0
# age_o         104
# race_o         73
# dec_o           0
# attr_o        212
# sinc_o        287
# intel_o       306
# fun_o         360
# amb_o         722
# shar_o       1076
# like_o        250
# age            95
# field          63
# field_cd       82
# race           63
# imprace        79
# imprelig       79
# attr1_1        79
# sinc1_1        79
# intel1_1       79
# fun1_1         89
# amb1_1         99
# shar1_1       121
# attr2_1        79
# sinc2_1        79
# intel2_1       79
# fun2_1         79
# amb2_1         89
# shar2_1        89
# dec             0
# attr          202
# sinc          277
# intel         296
# fun           350
# amb           712
# shar         1067
# like          240
# length        915
# numdat_2      945

# %%
#np.array(data.columns)

# %%
#Categorisation des matches:
matches = data.match.apply(lambda x: "yes" if x==1
                                      else "no" )
matches
# Out:
# 0        no
# 1        no
# 2       yes
# 3       yes
# 4       yes
#        ...
# 8373     no
# 8374     no
# 8375     no
# 8376     no
# 8377     no
# Name: match, Length: 8378, dtype: object

# %%
#Somme des match :
matches_count = matches.value_counts()
matches_count
# Out:
# no     6998
# yes    1380
# Name: match, dtype: int64

# %%
#Somme des match en % :
matches_count_percent = np.round((matches_count /(matches_count.sum()))*100,2)
matches_count_percent
# Out:
# no     83.53
# yes    16.47
# Name: match, dtype: float64

# %%
# Visualisation des "match" en %
fig, ax = plt.subplots(figsize = (8,5))
ax.bar( matches_count_percent.index, matches_count_percent.values )
plt.title(" Pourentage des match lors des dates")
plt.show()

# %%
#Catégorisation des decisions prises lors des dates:
decision = data.dec.apply(lambda x: "yes" if x ==1 
                                     else "no"
                                     )
decision.head()
# Out:
# 0    yes
# 1    yes
# 2    yes
# 3    yes
# 4    yes
# Name: dec, dtype: object

# %%
#Sum des décisions :
decision_count = decision.value_counts()
decision_count
# Out:
# no     4860
# yes    3518
# Name: dec, dtype: int64

# %%
#Somme des décisions en % :
decision_count_percent = np.round((decision_count /(decision_count.sum()))*100,2)
decision_count_percent
# Out:
# no     58.01
# yes    41.99
# Name: dec, dtype: float64

# %%
# Visualisation des décisions en %
fig, ax = plt.subplots(figsize = (8,5))
ax.bar(decision_count_percent.index, decision_count_percent.values)
plt.title("Pourcentage des déisions prises lors des dates ")
plt.show()

# %%
#Catégorisation des decisions prises par les partenaires lors des dates:
decision_o = data.dec_o.apply(lambda x: "yes" if x ==1 
                                     else "no")
decision_o.head()
# Out:
# 0     no
# 1     no
# 2    yes
# 3    yes
# 4    yes
# Name: dec_o, dtype: object

# %%
#Sum des decisions prises par les partenaires:
decision_o_count = decision_o.value_counts()
decision_o_count
# Out:
# no     4863
# yes    3515
# Name: dec_o, dtype: int64

# %%
#Somme des décisions prises par les partenaires en % :
decision_o_count_percent = np.round((decision_o_count /(decision_o_count.sum()))*100,2)
decision_o_count_percent
# Out:
# no     58.04
# yes    41.96
# Name: dec_o, dtype: float64

# %%
# Visualisation des décisions prises par les partenaires en %
fig, ax = plt.subplots(figsize = (8,5))
ax.bar(decision_o_count_percent.index, decision_o_count_percent.values)
plt.title("Pourcentage des déisions prises par les partenaires lors des dates ")
plt.show()

# %%
explode = [0.0,0.2]
# Création de trois graphiques via plt.subplot()
plt.figure(figsize=(8,8))

## Création du premier pie chart
plt.subplot(221)
plt.pie(decision_count, explode=explode,labels=decision_count.index, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.title("Decision at night of event")
plt.legend(decision_count, loc='upper left', bbox_to_anchor=(0,1))

## Création d'une seonde pie chart
plt.subplot(222)
plt.pie(decision_o_count, explode=explode,labels=decision_o_count.index, autopct='%1.1f%%',
        shadow=True, startangle=90)

plt.title("Decision of partner at night of event") 
plt.legend(decision_o_count, loc='upper left', bbox_to_anchor=(1,1)) 

## Création d'une troisième pie chart
plt.subplot(223)
plt.pie(matches_count, explode=explode,labels=matches_count.index, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.title("matches at night of event")
plt.legend(matches_count, loc='upper left', bbox_to_anchor=(0,1))

plt.show()

# %% [markdown]
# ---

# %%
#Importance des variables dans la description des matches
a = data.corr()
abs(a.match.sort_values(ascending=False))
# Out:
# match       1.000000
# dec_o       0.522326
# dec         0.521943
# like_o      0.305853
# like        0.305723
# fun_o       0.277700
# fun         0.277545
# shar_o      0.270840
# shar        0.270679
# attr_o      0.260837
# attr        0.260676
# intel       0.169532
# intel_o     0.169448
# sinc_o      0.164523
# sinc        0.164449
# amb         0.140042
# amb_o       0.139927
# fun1_1      0.041652
# int_corr    0.031121
# length      0.027721
# intel2_1    0.026303
# attr2_1     0.016455
# attr1_1     0.014950
# intel1_1    0.014087
# samerace    0.013028
# numdat_2    0.011126
# amb2_1      0.000028
# gender      0.000530
# amb1_1      0.004444
# fun2_1      0.009985
# race_o      0.013088
# race        0.013268
# sinc2_1     0.014294
# field_cd    0.024641
# imprelig    0.026014
# sinc1_1     0.032325
# age         0.035055
# age_o       0.035865
# shar2_1     0.037709
# shar1_1     0.048318
# imprace     0.049032
# Name: match, dtype: float64

# %%
data = data.drop(["amb2_1", "gender", "amb1_1", "fun2_1", "numdat_2", "samerace", "race_o", "race", "intel1_1", "sinc2_1", "attr1_1", "attr2_1", "field_cd", "imprelig", "intel2_1", "length", "int_corr", "sinc1_1", "age", "age_o", "shar2_1", "fun1_1", "shar1_1"], axis = 1)
data.head(6)
# Out:
#    match  dec_o  attr_o  sinc_o  intel_o  fun_o  amb_o  shar_o  like_o field  \
# 0      0      0     6.0     8.0      8.0    8.0    8.0     6.0     7.0   Law
# 1      0      0     7.0     8.0     10.0    7.0    7.0     5.0     8.0   Law
# 2      1      1    10.0    10.0     10.0   10.0   10.0    10.0    10.0   Law
# 3      1      1     7.0     8.0      9.0    8.0    9.0     8.0     7.0   Law
# 4      1      1     8.0     7.0      9.0    6.0    9.0     7.0     8.0   Law
# 5      0      1     7.0     7.0      8.0    8.0    7.0     7.0     7.0   Law
#
#    imprace  dec  attr  sinc  intel  fun  amb  shar  like
# 0      2.0    1   6.0   9.0    7.0  7.0  6.0   5.0   7.0
# 1      2.0    1   7.0   8.0    7.0  8.0  5.0   6.0   7.0
# 2      2.0    1   5.0   8.0    9.0  8.0  5.0   7.0   7.0
# 3      2.0    1   7.0   6.0    8.0  7.0  6.0   8.0   7.0
# 4      2.0    1   5.0   6.0    7.0  7.0  6.0   6.0   6.0
# 5      2.0    0   4.0   9.0    7.0  4.0  6.0   4.0   6.0

# %%
# Visualisation de la matrice de corrélation:
correlation = data.corr()
f, ax = plt.subplots(figsize=(20, 9))
ax = sns.heatmap(correlation, annot=True) 
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
data.head(6)
# Out:
#    match  dec_o  attr_o  sinc_o  intel_o  fun_o  amb_o  shar_o  like_o field  \
# 0      0      0     6.0     8.0      8.0    8.0    8.0     6.0     7.0   Law
# 1      0      0     7.0     8.0     10.0    7.0    7.0     5.0     8.0   Law
# 2      1      1    10.0    10.0     10.0   10.0   10.0    10.0    10.0   Law
# 3      1      1     7.0     8.0      9.0    8.0    9.0     8.0     7.0   Law
# 4      1      1     8.0     7.0      9.0    6.0    9.0     7.0     8.0   Law
# 5      0      1     7.0     7.0      8.0    8.0    7.0     7.0     7.0   Law
#
#    imprace  dec  attr  sinc  intel  fun  amb  shar  like
# 0      2.0    1   6.0   9.0    7.0  7.0  6.0   5.0   7.0
# 1      2.0    1   7.0   8.0    7.0  8.0  5.0   6.0   7.0
# 2      2.0    1   5.0   8.0    9.0  8.0  5.0   7.0   7.0
# 3      2.0    1   7.0   6.0    8.0  7.0  6.0   8.0   7.0
# 4      2.0    1   5.0   6.0    7.0  7.0  6.0   6.0   6.0
# 5      2.0    0   4.0   9.0    7.0  4.0  6.0   4.0   6.0

# %%
data.isnull().any()
# Out:
# match      False
# dec_o      False
# attr_o      True
# sinc_o      True
# intel_o     True
# fun_o       True
# amb_o       True
# shar_o      True
# like_o      True
# field       True
# imprace     True
# dec        False
# attr        True
# sinc        True
# intel       True
# fun         True
# amb         True
# shar        True
# like        True
# dtype: bool

# %%
data.dropna(inplace=True)
data.isnull().any()
# Out:
# match      False
# dec_o      False
# attr_o     False
# sinc_o     False
# intel_o    False
# fun_o      False
# amb_o      False
# shar_o     False
# like_o     False
# field      False
# imprace    False
# dec        False
# attr       False
# sinc       False
# intel      False
# fun        False
# amb        False
# shar       False
# like       False
# dtype: bool

# %%
# Visualisation de l'importance des "like" en fonction des "attr" de la part des partenaires dans la prise des decisions:
# like_o : affection de la partenaire 
# attr_o : attirance par la partenaire
# dec_o (0 == "no" & 1 == "yes") : decision de la partenaire des des dates 
sns.relplot(data = data, x= "attr_o", y = "like_o", hue="dec_o"  )
plt.show()

# %% [markdown]
# ==> On remaqrue qu'à partir d'une notation de "like_o" et "attr_o" >= 6, la prise de decision ("dec_o") à tendance à être "yes" chez la partenaire.

# %%
# Visualisation de l'importance des "like" en fonction des "attr" de la part des partenaires dans la prise des decisions:
# like:   affection  
# attr : l'attirance de la partenaire
# dec (0 == "no" & 1 == "yes") :  decision lors des dates
sns.relplot(data = data, x= "attr", y = "like", hue = "dec")
plt.show()

# %% [markdown]
# ==> Nous avons aussi une forte corrélation entre les notations de "like" et "attr" >= 6, donc la prise de decision ("dec") aura tendance à être "yes".
#
# On obtient un "match" en cas de decision favorable ("yes") de la part des 2 partenaires.
# Par conséquent,  nous pouvons supposer que ces variables sont importantes dans l'obtention d'une seconde date.
#
# En effet, nous partons du principe que l'obtention d'un "match" est synonyme d'une seconde date.

# %%
# Caracérisation de l'importance de la réligion lors des dates
imprace = data.imprace.apply(lambda x: "Absolument important(score=10)" if x==10
                                else "Extrêmement important(score=9)" if x ==9
                                else "Très Très important(score=8)" if x==8
                                else "Très important(score=7)" if x ==7
                                else "Important(score=6)" if x==6
                                else "moyen(score=5)" if x==5
                                else "Très peu important(score=4)" if x==4
                                else "Pas assez important(score=3)" if x==3
                                else "Pas important(score=2)" if x==2
                                else "Pas du tout important(score=1)" if x ==1
                                else "Totalement indifférent(score=0)")
imprace
# Out:
# 0               Pas important(score=2)
# 1               Pas important(score=2)
# 2               Pas important(score=2)
# 3               Pas important(score=2)
# 4               Pas important(score=2)
#                      ...
# 8367    Pas du tout important(score=1)
# 8368    Pas du tout important(score=1)
# 8369    Pas du tout important(score=1)
# 8370    Pas du tout important(score=1)
# 8377    Pas du tout important(score=1)
# Name: imprace, Length: 5928, dtype: object

# %%
imprace_count = imprace.value_counts().sort_values()
imprace_count
# Out:
# Totalement indifférent(score=0)       6
# Absolument important(score=10)      165
# Très peu important(score=4)         309
# Extrêmement important(score=9)      335
# Important(score=6)                  375
# Très important(score=7)             379
# moyen(score=5)                      464
# Très Très important(score=8)        523
# Pas important(score=2)              708
# Pas assez important(score=3)        761
# Pas du tout important(score=1)     1903
# Name: imprace, dtype: int64

# %%
# Visualisation de l'importance de la réligion lors des dates
fig, ax = plt.subplots(figsize = (10,6))
ax.barh(imprace_count.index, imprace_count.values)
plt.title("L'importance d'avoir la même réligion chez les 2 partenaires")
plt.xlabel("Somme des notes attribuées par les participants")
plt.show()
